# %%
import requests
from urllib.parse import urlparse, urljoin
from bs4 import BeautifulSoup
import colorama


# init the colorama module
# use colorama just for using different colors when printing, to distinguish between internal and external links:
colorama.init()
GREEN = colorama.Fore.GREEN
GRAY = colorama.Fore.LIGHTBLACK_EX
RESET = colorama.Fore.RESET


# initialize the set of links (unique links)
internal_urls = set()
external_urls = set()


def is_valid(url):
    """
    Checks whether `url` is a valid URL.
    """
    parsed = urlparse(url)
    return bool(parsed.netloc) and bool(parsed.scheme)


def get_all_website_links(url):
    """
    Returns all URLs that is found on `url` in which it belongs to the same website
    """
    # all URLs of `url`
    urls = set()
    # domain name of the URL without the protocol
    domain_name = urlparse(url).netloc
    soup = BeautifulSoup(requests.get(url).content, "html.parser")
    
    for a_tag in soup.findAll("a"):
        href = a_tag.attrs.get("href")
        if href == "" or href is None:
            # href empty tag
            continue
        # join the URL if it's relative (not absolute link)
        href = urljoin(url, href)
        parsed_href = urlparse(href)
        # remove URL GET parameters, URL fragments, etc.
        href = parsed_href.scheme + "://" + parsed_href.netloc + parsed_href.path
        if not is_valid(href):
            # not a valid URL
            continue
        if href in internal_urls:
            # already in the set
            continue
        if domain_name not in href:
            # external link
            if href not in external_urls:
                print(f"{GRAY}[!] External link: {href}{RESET}")
                external_urls.add(href)
            continue
        print(f"{GREEN}[*] Internal link: {href}{RESET}")
        urls.add(href)
        internal_urls.add(href)
    return urls

# number of urls visited so far will be stored here
total_urls_visited = 0

def crawl(url, max_urls=100):
    """
    Crawls a web page and extracts all links.
    You'll find all links in `external_urls` and `internal_urls` global set variables.
    params:
        max_urls (int): number of max urls to crawl, default is 100.
    """
    global total_urls_visited
    total_urls_visited += 1
    links = get_all_website_links(url)
    for link in links:
        if total_urls_visited > max_urls:
            break
        crawl(link, max_urls=max_urls)

# %%
crawl('https://www.immoweb.be/en')
print("[+] Total External links:", len(external_urls))
print("[+] Total Internal links:", len(internal_urls))
print("[+] Total:", len(external_urls) + len(internal_urls))
# Out:
# [*] Internal link: https://www.immoweb.be/en
# [*] Internal link: https://www.immoweb.be/en/search/house-and-apartment/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/house-and-apartment/for-rent
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/house/for-rent
# [*] Internal link: https://www.immoweb.be/en/search/apartment/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/apartment/for-rent
# [*] Internal link: https://www.immoweb.be/en/page/about-immoweb
# [*] Internal link: https://www.immoweb.be/en/page/the-immoweb-newsroom
# [!] External link: https://www.linkedin.com/company/immoweb/jobs/
# [!] External link: https://www.axelspringer.com/en/
# [!] External link: https://valuation.immoweb.be/real-estate-estimate/seg1
# [!] External link: https://www.constructr.be/en
# [*] Internal link: https://www.immoweb.be/en/credit-application
# [!] External link: https://protect.immoweb.be/tenant-home-insurance/landing
# [*] Internal link: https://www.immoweb.be/en/frequently-asked-questions
# [*] Internal link: https://www.immoweb.be/en/page/fraud
# [*] Internal link: https://www.immoweb.be/en/page/accessibility
# [*] Internal link: https://www.immoweb.be/en/page/contact-us
# [!] External link: https://www.facebook.com/immoweb
# [!] External link: https://twitter.com/immoweb
# [!] External link: https://www.linkedin.com/company/immoweb
# [*] Internal link: https://www.immoweb.be/en/page/terms-of-use
# [*] Internal link: https://www.immoweb.be/en/page/privacy
# [!] External link: https://www.cim.be/fr/internet/disclaimer-cim-internet
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.immoweb.be/en/page/privacy
# [!] External link: https://web.archive.org/web/20200328055930mp_/https://www.keytradebank.be/en/privacy-policy/
# [*] Internal link: https://www.immoweb.be/cdn-cgi/l/email-protection
# [!] External link: https://web.archive.org/web/20200328055930mp_/https://valuation.immoweb.be/
# [!] External link: https://web.archive.org/web/20200328055930mp_/https://laura.immoweb.be/en
# [!] External link: https://web.archive.org/web/20200328055930mp_/https://docs.immoweb.be/fr
# [!] External link: https://web.archive.org/web/20200328055930mp_/https://protect.immoweb.be/
# [!] External link: https://web.archive.org/web/20200328055930mp_/https://www.qover.com/terms-policies/data
# [!] External link: https://web.archive.org/web/20200328055930mp_/http://protect.immoweb.be/
# [!] External link: https://web.archive.org/web/20200328055930mp_/http://www.homestamp.io/
# [!] External link: https://web.archive.org/web/20200328055930mp_/https://blog.immoweb.be/fr/
# [!] External link: https://web.archive.org/web/20200328055930mp_/http://tools.google.com/dlpage/gaoptout
# [!] External link: https://web.archive.org/web/20200328055930mp_/https://support.google.com/analytics/answer/6004245
# [!] External link: https://web.archive.org/web/20200328055930mp_/http://www.facebook.com/policy.php
# [!] External link: https://web.archive.org/web/20200328055930mp_/https://twitter.com/privacy
# [!] External link: https://web.archive.org/web/20200328055930mp_/https://help.instagram.com/155833707900388
# [!] External link: https://web.archive.org/web/20200328055930mp_/https://policies.google.com/privacy
# [!] External link: https://web.archive.org/web/20200328055930mp_/https://www.linkedin.com/legal/privacy-policy
# [!] External link: https://web.archive.org/web/20200328055930mp_/https://www.dataprotectionauthority.be/
# [!] External link: https://www.cloudflare.com/sign-up
# [!] External link: https://support.cloudflare.com/hc/en-us/articles/200170016-What-is-Email-Address-Obfuscation-
# [!] External link: https://support.cloudflare.com/hc/en-us/categories/200275218-Getting-Started
# [!] External link: https://www.cloudflare.com/5xx-error-landing
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.keytradebank.be/en/privacy-policy/
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.immoweb.be/cdn-cgi/l/email-protection
# [*] Internal link: https://web.archive.org/web/20200328055930/https://valuation.immoweb.be/
# [*] Internal link: https://web.archive.org/web/20200328055930/https://laura.immoweb.be/en
# [*] Internal link: https://web.archive.org/web/20200328055930/https://docs.immoweb.be/fr
# [*] Internal link: https://web.archive.org/web/20200328055930/https://protect.immoweb.be/
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.qover.com/terms-policies/data
# [*] Internal link: https://web.archive.org/web/20200328055930/http://protect.immoweb.be/
# [*] Internal link: https://web.archive.org/web/20200328055930/http://www.homestamp.io/
# [*] Internal link: https://web.archive.org/web/20200328055930/https://blog.immoweb.be/fr/
# [*] Internal link: https://web.archive.org/web/20200328055930/http://tools.google.com/dlpage/gaoptout
# [*] Internal link: https://web.archive.org/web/20200328055930/https://support.google.com/analytics/answer/6004245
# [*] Internal link: https://web.archive.org/web/20200328055930/http://www.facebook.com/policy.php
# [*] Internal link: https://web.archive.org/web/20200328055930/https://twitter.com/privacy
# [*] Internal link: https://web.archive.org/web/20200328055930/https://help.instagram.com/155833707900388
# [*] Internal link: https://web.archive.org/web/20200328055930/https://policies.google.com/privacy
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.linkedin.com/legal/privacy-policy
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.dataprotectionauthority.be/
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.immoweb.be/page/terms-of-use
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.immoweb.be/en/search/house-and-apartment/for-sale
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.immoweb.be/en/search/house-and-apartment/for-rent
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.immoweb.be/en/search/house/for-sale
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.immoweb.be/en/search/house/for-rent
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.immoweb.be/en/search/apartment/for-sale
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.immoweb.be/en/search/apartment/for-rent
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.immoweb.be/en/page/about-immoweb
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.immoweb.be/en/page/the-immoweb-newsroom
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.linkedin.com/company/immoweb/jobs/
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.axelspringer.com/en/
# [*] Internal link: https://web.archive.org/web/20200328055930/https://valuation.immoweb.be/real-estate-estimate/seg1
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.constructr.be/en
# [*] Internal link: https://web.archive.org/web/20200328055930/https://protect.immoweb.be/tenant-home-insurance/landing
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.immoweb.be/en/frequently-asked-questions
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.immoweb.be/en/page/fraud
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.immoweb.be/en/page/accessibility
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.immoweb.be/en/page/contact-us
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.facebook.com/immoweb
# [*] Internal link: https://web.archive.org/web/20200328055930/https://twitter.com/immoweb
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.linkedin.com/company/immoweb
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.immoweb.be/en/page/terms-of-use
# [*] Internal link: https://web.archive.org/web/20200328055930/https://www.cim.be/fr/internet/disclaimer-cim-internet
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.w3.org/WAI/standards-guidelines/wcag/
# [*] Internal link: https://web.archive.org/web/20200719235022/https://support.apple.com/en-us/HT204434
# [*] Internal link: https://web.archive.org/web/20200719235022/https://support.microsoft.com/en-gb/help/13862/windows-10-use-high-contrast-mode
# [*] Internal link: https://web.archive.org/web/20200719235022/https://immoweb.be/en/page/privacy
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.immoweb.be/cdn-cgi/l/email-protection
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.immoweb.be/en/search/house-and-apartment/for-sale
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.immoweb.be/en/search/house-and-apartment/for-rent
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.immoweb.be/en/search/house/for-sale
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.immoweb.be/en/search/house/for-rent
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.immoweb.be/en/search/apartment/for-sale
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.immoweb.be/en/search/apartment/for-rent
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.immoweb.be/en/page/about-immoweb
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.immoweb.be/en/page/the-immoweb-newsroom
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.linkedin.com/company/immoweb/jobs/
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.axelspringer.com/en/
# [*] Internal link: https://web.archive.org/web/20200719235022/https://valuation.immoweb.be/real-estate-estimate/seg1
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.constructr.be/en
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.immoweb.be/en/credit-application
# [*] Internal link: https://web.archive.org/web/20200719235022/https://protect.immoweb.be/tenant-home-insurance/landing
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.immoweb.be/en/frequently-asked-questions
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.immoweb.be/en/page/fraud
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.immoweb.be/en/page/accessibility
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.immoweb.be/en/page/contact-us
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.facebook.com/immoweb
# [*] Internal link: https://web.archive.org/web/20200719235022/https://twitter.com/immoweb
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.linkedin.com/company/immoweb
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.immoweb.be/en/page/terms-of-use
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.immoweb.be/en/page/privacy
# [*] Internal link: https://web.archive.org/web/20200719235022/https://www.cim.be/fr/internet/disclaimer-cim-internet
# [*] Internal link: https://web.archive.org/web/20200718174108/https://web.archive.org/web/20200328055930/https://www.immoweb.be/en/page/privacy
# [*] Internal link: https://web.archive.org/web/20200718174108/https://web.archive.org/web/20200328055930mp_/https://www.keytradebank.be/en/privacy-policy/
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.immoweb.be/cdn-cgi/l/email-protection
# [*] Internal link: https://web.archive.org/web/20200718174108/https://web.archive.org/web/20200328055930mp_/https://valuation.immoweb.be/
# [*] Internal link: https://web.archive.org/web/20200718174108/https://web.archive.org/web/20200328055930mp_/https://laura.immoweb.be/en
# [*] Internal link: https://web.archive.org/web/20200718174108/https://web.archive.org/web/20200328055930mp_/https://docs.immoweb.be/fr
# [*] Internal link: https://web.archive.org/web/20200718174108/https://web.archive.org/web/20200328055930mp_/https://protect.immoweb.be/
# [*] Internal link: https://web.archive.org/web/20200718174108/https://web.archive.org/web/20200328055930mp_/https://www.qover.com/terms-policies/data
# [*] Internal link: https://web.archive.org/web/20200718174108/https://web.archive.org/web/20200328055930mp_/http://protect.immoweb.be/
# [*] Internal link: https://web.archive.org/web/20200718174108/https://web.archive.org/web/20200328055930mp_/http://www.homestamp.io/
# [*] Internal link: https://web.archive.org/web/20200718174108/https://web.archive.org/web/20200328055930mp_/https://blog.immoweb.be/fr/
# [*] Internal link: https://web.archive.org/web/20200718174108/https://web.archive.org/web/20200328055930mp_/http://tools.google.com/dlpage/gaoptout
# [*] Internal link: https://web.archive.org/web/20200718174108/https://web.archive.org/web/20200328055930mp_/https://support.google.com/analytics/answer/6004245
# [*] Internal link: https://web.archive.org/web/20200718174108/https://web.archive.org/web/20200328055930mp_/http://www.facebook.com/policy.php
# [*] Internal link: https://web.archive.org/web/20200718174108/https://web.archive.org/web/20200328055930mp_/https://twitter.com/privacy
# [*] Internal link: https://web.archive.org/web/20200718174108/https://web.archive.org/web/20200328055930mp_/https://help.instagram.com/155833707900388
# [*] Internal link: https://web.archive.org/web/20200718174108/https://web.archive.org/web/20200328055930mp_/https://policies.google.com/privacy
# [*] Internal link: https://web.archive.org/web/20200718174108/https://web.archive.org/web/20200328055930mp_/https://www.linkedin.com/legal/privacy-policy
# [*] Internal link: https://web.archive.org/web/20200718174108/https://web.archive.org/web/20200328055930mp_/https://www.dataprotectionauthority.be/
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.immoweb.be/en/search/house-and-apartment/for-sale
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.immoweb.be/en/search/house-and-apartment/for-rent
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.immoweb.be/en/search/house/for-sale
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.immoweb.be/en/search/house/for-rent
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.immoweb.be/en/search/apartment/for-sale
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.immoweb.be/en/search/apartment/for-rent
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.immoweb.be/en/page/about-immoweb
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.immoweb.be/en/page/the-immoweb-newsroom
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.linkedin.com/company/immoweb/jobs/
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.axelspringer.com/en/
# [*] Internal link: https://web.archive.org/web/20200718174108/https://valuation.immoweb.be/real-estate-estimate/seg1
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.constructr.be/en
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.immoweb.be/en/credit-application
# [*] Internal link: https://web.archive.org/web/20200718174108/https://protect.immoweb.be/tenant-home-insurance/landing
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.immoweb.be/en/frequently-asked-questions
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.immoweb.be/en/page/fraud
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.immoweb.be/en/page/accessibility
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.immoweb.be/en/page/contact-us
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.facebook.com/immoweb
# [*] Internal link: https://web.archive.org/web/20200718174108/https://twitter.com/immoweb
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.linkedin.com/company/immoweb
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.immoweb.be/en/page/terms-of-use
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.immoweb.be/en/page/privacy
# [*] Internal link: https://web.archive.org/web/20200718174108/https://www.cim.be/fr/internet/disclaimer-cim-internet
# [!] External link: http://blog.archive.org/2020/06/10/temporary-national-emergency-library-to-close-2-weeks-early-returning-to-traditional-controlled-digital-lending/
# [!] External link: https://archive.org
# [!] External link: https://archive.org/create/
# [!] External link: https://archive.org/account/signup
# [!] External link: https://archive.org/account/login
# [!] External link: https://archive.org/web/
# [!] External link: https://archive.org/details/texts
# [!] External link: https://archive.org/details/movies
# [!] External link: https://archive.org/details/audio
# [!] External link: https://archive.org/details/software
# [!] External link: https://archive.org/details/image
# [!] External link: https://archive.org/donate/
# [!] External link: https://archive.org/about/
# [!] External link: https://blog.archive.org/
# [!] External link: https://archive.org/projects/
# [!] External link: https://archive.org/about/faqs.php
# [!] External link: https://archive.org/about/contact.php
# [!] External link: https://archive.org/about/jobs.php
# [!] External link: https://archive.org/about/volunteerpositions.php
# [!] External link: https://archive.org/about/bios.php
# [!] External link: https://archive.org/advancedsearch.php
# [!] External link: http://archive.org/donate/
# [*] Internal link: https://web.archive.org/
# [*] Internal link: https://web.archive.org/web/*/https://web.archive.org/web/20200328055930mp_/https://help.instagram.com/*
# [!] External link: mailto://info@archive.org
# [!] External link: https://archive.org/
# [!] External link: https://openlibrary.org/
# [!] External link: https://archive-it.org
# [!] External link: https://archive.org/about/terms.php
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.immoweb.be/cdn-cgi/l/email-protection
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.immoweb.be/en/search/house-and-apartment/for-sale
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.immoweb.be/en/search/house-and-apartment/for-rent
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.immoweb.be/en/search/house/for-sale
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.immoweb.be/en/search/house/for-rent
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.immoweb.be/en/search/apartment/for-sale
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.immoweb.be/en/search/apartment/for-rent
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.immoweb.be/en/page/about-immoweb
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.immoweb.be/en/page/the-immoweb-newsroom
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.linkedin.com/company/immoweb/jobs/
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.axelspringer.com/en/
# [*] Internal link: https://web.archive.org/web/20200724084755/https://valuation.immoweb.be/real-estate-estimate/seg1
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.constructr.be/en
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.immoweb.be/en/credit-application
# [*] Internal link: https://web.archive.org/web/20200724084755/https://protect.immoweb.be/tenant-home-insurance/landing
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.immoweb.be/en/frequently-asked-questions
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.immoweb.be/en/page/fraud
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.immoweb.be/en/page/accessibility
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.immoweb.be/en/page/contact-us
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.facebook.com/immoweb
# [*] Internal link: https://web.archive.org/web/20200724084755/https://twitter.com/immoweb
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.linkedin.com/company/immoweb
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.immoweb.be/en/page/terms-of-use
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.immoweb.be/en/page/privacy
# [*] Internal link: https://web.archive.org/web/20200724084755/https://www.cim.be/fr/internet/disclaimer-cim-internet
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/search-projects
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/register
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/login
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/nl
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/nl/project/extension-contemporaine-en-zinc-pigmento-rouge-de-vmzinc/vmzinc/hedendaags-renovatie-zink-nieuw-huis-nieuwbouw
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/project/duplo-pure/induscabel/0-10-000-modern-bathroom-shower-glass-grey
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/project/hamoir/christophe-ternest-sprl/0-1-000-000-wood-new-apartment-luminosity-parquet
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/project/bl234/blavier/classic-house-bathroom-bedroom
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/project/r-novation-hall-d-entr-e/bureau-d-architecture-fr-d-ric-fromentin/renovation-house-single-family-stairs
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/project/extension-d-une-habitation-1/bureau-d-architecture-fr-d-ric-fromentin/extension-brick-classic-house
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/project/vakil/in-situ/facade-panels-modern-apartment-zinc
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/project/arcos-5/centre-conseil-schmidt-1/white-modern-new-kitchen-tap
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/project/cabinet-m-dical-attenant-une-habitation/bureau-d-architectes-desmedt-purnelle/white-extension-modern-renovation-house
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/project/imagine/facq/0-10-000-modern-bathroom
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/project/comment-choisir-son-architecte/constructr
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/project/douche-ou-bain/facq/bathroom-shower-room-shower-bath
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/project/velux-lumiere-maison-renovation/velux/modern-renovation-roof-window-nouvelle-maison
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/project/demenagement-laura/immoweb/renovation
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/project/primes-a-la-renovation/reynaers-aluminium/renovation-frames
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/project/concevez-votre-salle-de-bains/facq/modern-bathroom-tailored
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/search-professionals
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/search-projects
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/search-professionals
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/register
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/register/professional/choose-package
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/about-us
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/privacy-policy
# [*] Internal link: https://web.archive.org/web/20200114215630/https://www.constructr.be/en/cookie-policy
# [*] Internal link: https://web.archive.org/web/20200904064007/https://www.constructr.be/en
# [*] Internal link: https://web.archive.org/web/20200904064007/https://www.constructr.be/en/search-projects
# [*] Internal link: https://web.archive.org/web/20200904064007/https://www.constructr.be/en/register
# [*] Internal link: https://web.archive.org/web/20200904064007/https://www.constructr.be/en/login
# [*] Internal link: https://web.archive.org/web/20200904064007/https://www.constructr.be/en/project/cabinet-m-dical-attenant-une-habitation/bureau-d-architectes-desmedt-purnelle/white-extension-modern-renovation-house
# [*] Internal link: https://web.archive.org/web/20200904064007/https://www.constructr.be/project/cabinet-m-dical-attenant-une-habitation/bureau-d-architectes-desmedt-purnelle/white-extension-modern-renovation-house
# [*] Internal link: https://web.archive.org/web/20200904064007/https://www.constructr.be/nl/project/cabinet-m-dical-attenant-une-habitation/bureau-d-architectes-desmedt-purnelle/white-extension-modern-renovation-house
# [*] Internal link: https://web.archive.org/web/20200904064007/https://www.constructr.be/en/professional/bureau-d-architectes-desmedt-purnelle
# [*] Internal link: https://web.archive.org/web/20200904064007/https://www.constructr.be/en/project/maison-unifamiliale/bureau-d-architectes-desmedt-purnelle/modern-new-house
# [*] Internal link: https://web.archive.org/web/20200904064007/https://www.constructr.be/en/project/maison-passive-nam-che/bureau-d-architectes-desmedt-purnelle/white-passive-modern-new-house
# [*] Internal link: https://web.archive.org/web/20200904064007/https://www.constructr.be/en/project/extension-en-bois-1/bureau-d-architectes-desmedt-purnelle/extension-wood-modern-house-bay-window
# [*] Internal link: https://web.archive.org/web/20200904064007/https://www.constructr.be/
# [*] Internal link: https://web.archive.org/web/20200904064007/https://www.constructr.be/search-projects
# [*] Internal link: https://web.archive.org/web/20200904064007/https://www.constructr.be/search-professionals
# [*] Internal link: https://web.archive.org/web/20200904064007/https://www.constructr.be/register
# [*] Internal link: https://web.archive.org/web/20200904064007/https://www.constructr.be/register/professional/choose-package
# [*] Internal link: https://web.archive.org/web/20200904064007/https://www.constructr.be/en/about-us
# [*] Internal link: https://web.archive.org/web/20200904064007/https://www.constructr.be/en/privacy-policy
# [*] Internal link: https://web.archive.org/web/20200904064007/https://www.constructr.be/en/cookie-policy
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/search-projects
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/register
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/login
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/en/search-professionals
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/search-professionals
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/nl/search-professionals
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/achtoptien-architect-en-interieur
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/audrey-muller
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/constructr
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/a3-development-sprl
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/buro-5
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/architectenbureau-bressers
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/tuinen-joos-bvba
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/domus-concept-s-a
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/atelierphi
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/sa-christian-devall-e-architecte-paysagiste-entrepreneur-de-jardin
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/bcarchitects
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/edouard-brunet-architecte
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/moonarchitects-bvba
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/blockoffice-architecten
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/db-architecten-bvba
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/lenchant-creative
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/fran-ois-smal-s-p-r-l
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/synopsis-architecture
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/fero-1
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/brix-architecture
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/atelier-d-architecture-nicolas-gillot
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/a-cube-architecture
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/architectuur-in-t-stad
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/professional/crahay-jamaigne
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/fr/about-us
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/fr/privacy-policy
# [*] Internal link: https://web.archive.org/web/20200114220020/https://www.constructr.be/fr/cookie-policy
# [*] Internal link: https://web.archive.org/web/20200114220020/http://www.constructr.be/cookie-policy
# [*] Internal link: https://web.archive.org/web/20200904064020/https://www.constructr.be/
# [*] Internal link: https://web.archive.org/web/20200904064020/https://www.constructr.be/search-projects
# [*] Internal link: https://web.archive.org/web/20200904064020/https://www.constructr.be/register
# [*] Internal link: https://web.archive.org/web/20200904064020/https://www.constructr.be/login
# [*] Internal link: https://web.archive.org/web/20200904064020/https://www.constructr.be/en/professional/brix-architecture
# [*] Internal link: https://web.archive.org/web/20200904064020/https://www.constructr.be/professional/brix-architecture
# [*] Internal link: https://web.archive.org/web/20200904064020/https://www.constructr.be/nl/professional/brix-architecture
# [*] Internal link: https://web.archive.org/web/20200904064020/https://www.constructr.be/search-professionals
# [*] Internal link: https://web.archive.org/web/20200904064020/https://ad.doubleclick.net/ddm/trackclk/N4472.1918404CONSTRUCTR.BE/B23702129.273382105
# [*] Internal link: https://web.archive.org/web/20200904064020/https://www.constructr.be/project/renovation-interieure-durbuy/brix-architecture/contemporain-renovation-unifamiliale-grange-metal-interior
# [*] Internal link: https://web.archive.org/web/20200904064020/https://www.constructr.be/project/renovation-grange-a-theux/brix-architecture/extension-pierre-contemporain-ossature-bois-renovation-maison-grange-baie-vitree
# [*] Internal link: https://web.archive.org/web/20200904064020/https://www.constructr.be/project/maison-unifamiliale-a-la-bruyere/brix-architecture/blanc-crepis-beton-contemporain-neuve-maison-aluminium
# [*] Internal link: https://web.archive.org/web/20200904064020/https://www.constructr.be/fr/about-us
# [*] Internal link: https://web.archive.org/web/20200904064020/https://www.constructr.be/fr/privacy-policy
# [*] Internal link: https://web.archive.org/web/20200904064020/https://www.constructr.be/fr/cookie-policy
# [*] Internal link: https://web.archive.org/web/20200904064020/http://www.constructr.be/cookie-policy
# [*] Internal link: https://web.archive.org/web/20200114215553/https://www.constructr.be/
# [*] Internal link: https://web.archive.org/web/20200114215553/https://www.constructr.be/search-projects
# [*] Internal link: https://web.archive.org/web/20200114215553/https://www.constructr.be/register
# [*] Internal link: https://web.archive.org/web/20200114215553/https://www.constructr.be/login
# [*] Internal link: https://web.archive.org/web/20200114215553/https://www.constructr.be/en/login
# [*] Internal link: https://web.archive.org/web/20200114215553/https://www.constructr.be/nl/login
# [*] Internal link: https://web.archive.org/web/20200114215553/https://www.constructr.be/fr/cookie-policy
# [*] Internal link: https://web.archive.org/web/20200114215553/https://www.constructr.be/reset-password
# [*] Internal link: https://web.archive.org/web/20200114215553/https://www.constructr.be/search-professionals
# [*] Internal link: https://web.archive.org/web/20200114215553/https://www.constructr.be/fr/about-us
# [*] Internal link: https://web.archive.org/web/20200114215553/https://www.constructr.be/fr/privacy-policy
# [*] Internal link: https://web.archive.org/web/20200114215553/http://www.constructr.be/cookie-policy
# [*] Internal link: https://web.archive.org/web/20200114215915/https://www.constructr.be/
# [*] Internal link: https://web.archive.org/web/20200114215915/https://www.constructr.be/search-projects
# [*] Internal link: https://web.archive.org/web/20200114215915/https://www.constructr.be/register
# [*] Internal link: https://web.archive.org/web/20200114215915/https://www.constructr.be/login
# [*] Internal link: https://web.archive.org/web/20200114215915/https://www.constructr.be/en/register
# [*] Internal link: https://web.archive.org/web/20200114215915/https://www.constructr.be/nl/register
# [*] Internal link: https://web.archive.org/web/20200114215915/https://www.constructr.be/fr/privacy-policy
# [*] Internal link: https://web.archive.org/web/20200114215915/https://www.constructr.be/fr/cookie-policy
# [*] Internal link: https://web.archive.org/web/20200114215915/https://www.constructr.be/register/professional/choose-package
# [*] Internal link: https://web.archive.org/web/20200114215915/https://www.constructr.be/search-professionals
# [*] Internal link: https://web.archive.org/web/20200114215915/https://www.constructr.be/fr/about-us
# [*] Internal link: https://web.archive.org/web/20200114215915/http://www.constructr.be/cookie-policy
# [*] Internal link: https://web.archive.org/web/20200114215637/https://www.constructr.be/
# [*] Internal link: https://web.archive.org/web/20200114215637/https://www.constructr.be/search-projects
# [*] Internal link: https://web.archive.org/web/20200114215637/https://www.constructr.be/register
# [*] Internal link: https://web.archive.org/web/20200114215637/https://www.constructr.be/login
# [*] Internal link: https://web.archive.org/web/20200114215637/https://www.constructr.be/en/cookie-policy
# [*] Internal link: https://web.archive.org/web/20200114215637/https://www.constructr.be/cookie-policy
# [*] Internal link: https://web.archive.org/web/20200114215637/https://www.constructr.be/nl/cookie-policy
# [*] Internal link: https://web.archive.org/web/20200114215637/mailto:privacy@constructr.be
# [*] Internal link: https://web.archive.org/web/20200114215637/mailto:privacy@immoweb.be
# [*] Internal link: https://web.archive.org/web/20200114215637/https://www.constructr.be/search-professionals
# [*] Internal link: https://web.archive.org/web/20200114215637/https://www.constructr.be/fr/about-us
# [*] Internal link: https://web.archive.org/web/20200114215637/https://www.constructr.be/fr/privacy-policy
# [*] Internal link: https://web.archive.org/web/20200114215637/https://www.constructr.be/fr/cookie-policy
# [*] Internal link: https://web.archive.org/web/20200114215637/http://www.constructr.be/cookie-policy
# [*] Internal link: https://web.archive.org/web/20200904064045/https://www.constructr.be/en
# [*] Internal link: https://web.archive.org/web/20200904064045/https://www.constructr.be/en/search-projects
# [*] Internal link: https://web.archive.org/web/20200904064045/https://www.constructr.be/en/register
# [*] Internal link: https://web.archive.org/web/20200904064045/https://www.constructr.be/en/login
# [*] Internal link: https://web.archive.org/web/20200904064045/https://www.constructr.be/en/cookie-policy
# [*] Internal link: https://web.archive.org/web/20200904064045/https://www.constructr.be/cookie-policy
# [*] Internal link: https://web.archive.org/web/20200904064045/https://www.constructr.be/nl/cookie-policy
# [*] Internal link: https://web.archive.org/web/20200904064045/mailto:privacy@constructr.be
# [*] Internal link: https://web.archive.org/web/20200904064045/mailto:privacy@immoweb.be
# [*] Internal link: https://web.archive.org/web/20200904064045/https://www.constructr.be/
# [*] Internal link: https://web.archive.org/web/20200904064045/https://www.constructr.be/search-projects
# [*] Internal link: https://web.archive.org/web/20200904064045/https://www.constructr.be/search-professionals
# [*] Internal link: https://web.archive.org/web/20200904064045/https://www.constructr.be/register
# [*] Internal link: https://web.archive.org/web/20200904064045/https://www.constructr.be/register/professional/choose-package
# [*] Internal link: https://web.archive.org/web/20200904064045/https://www.constructr.be/en/about-us
# [*] Internal link: https://web.archive.org/web/20200904064045/https://www.constructr.be/en/privacy-policy
# [*] Internal link: https://web.archive.org/web/20200904064056/https://www.constructr.be/en
# [*] Internal link: https://web.archive.org/web/20200904064056/https://www.constructr.be/en/search-projects
# [*] Internal link: https://web.archive.org/web/20200904064056/https://www.constructr.be/en/register
# [*] Internal link: https://web.archive.org/web/20200904064056/https://www.constructr.be/en/login
# [*] Internal link: https://web.archive.org/web/20200904064056/https://www.constructr.be/register
# [*] Internal link: https://web.archive.org/web/20200904064056/https://www.constructr.be/nl/register
# [*] Internal link: https://web.archive.org/web/20200904064056/https://www.constructr.be/en/privacy-policy
# [*] Internal link: https://web.archive.org/web/20200904064056/https://www.constructr.be/en/cookie-policy
# [*] Internal link: https://web.archive.org/web/20200904064056/https://www.constructr.be/en/register/professional/choose-package
# [*] Internal link: https://web.archive.org/web/20200904064056/https://www.constructr.be/
# [*] Internal link: https://web.archive.org/web/20200904064056/https://www.constructr.be/search-projects
# [*] Internal link: https://web.archive.org/web/20200904064056/https://www.constructr.be/search-professionals
# [*] Internal link: https://web.archive.org/web/20200904064056/https://www.constructr.be/register/professional/choose-package
# [*] Internal link: https://web.archive.org/web/20200904064056/https://www.constructr.be/en/about-us
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-6603612fec18> in <module>
# ----> 1 crawl('https://www.immoweb.be/en')
#       2 print("[+] Total External links:", len(external_urls))
#       3 print("[+] Total Internal links:", len(internal_urls))
#       4 print("[+] Total:", len(external_urls) + len(internal_urls))
#
# <ipython-input-65-a7852a03fcc4> in crawl(url, max_urls)
#      79         if total_urls_visited > max_urls:
#      80             break
# ---> 81         crawl(link, max_urls=max_urls)
#
# <ipython-input-65-a7852a03fcc4> in crawl(url, max_urls)
#      79         if total_urls_visited > max_urls:
#      80             break
# ---> 81         crawl(link, max_urls=max_urls)
#
# <ipython-input-65-a7852a03fcc4> in crawl(url, max_urls)
#      79         if total_urls_visited > max_urls:
#      80             break
# ---> 81         crawl(link, max_urls=max_urls)
#
# <ipython-input-65-a7852a03fcc4> in crawl(url, max_urls)
#      79         if total_urls_visited > max_urls:
#      80             break
# ---> 81         crawl(link, max_urls=max_urls)
#
# <ipython-input-65-a7852a03fcc4> in crawl(url, max_urls)
#      79         if total_urls_visited > max_urls:
#      80             break
# ---> 81         crawl(link, max_urls=max_urls)
#
# <ipython-input-65-a7852a03fcc4> in crawl(url, max_urls)
#      79         if total_urls_visited > max_urls:
#      80             break
# ---> 81         crawl(link, max_urls=max_urls)
#
# <ipython-input-65-a7852a03fcc4> in crawl(url, max_urls)
#      79         if total_urls_visited > max_urls:
#      80             break
# ---> 81         crawl(link, max_urls=max_urls)
#
# <ipython-input-65-a7852a03fcc4> in crawl(url, max_urls)
#      79         if total_urls_visited > max_urls:
#      80             break
# ---> 81         crawl(link, max_urls=max_urls)
#
# <ipython-input-65-a7852a03fcc4> in crawl(url, max_urls)
#      79         if total_urls_visited > max_urls:
#      80             break
# ---> 81         crawl(link, max_urls=max_urls)
#
# <ipython-input-65-a7852a03fcc4> in crawl(url, max_urls)
#      79         if total_urls_visited > max_urls:
#      80             break
# ---> 81         crawl(link, max_urls=max_urls)
#
# <ipython-input-65-a7852a03fcc4> in crawl(url, max_urls)
#      79         if total_urls_visited > max_urls:
#      80             break
# ---> 81         crawl(link, max_urls=max_urls)
#
# <ipython-input-65-a7852a03fcc4> in crawl(url, max_urls)
#      79         if total_urls_visited > max_urls:
#      80             break
# ---> 81         crawl(link, max_urls=max_urls)
#
# <ipython-input-65-a7852a03fcc4> in crawl(url, max_urls)
#      79         if total_urls_visited > max_urls:
#      80             break
# ---> 81         crawl(link, max_urls=max_urls)
#
# <ipython-input-65-a7852a03fcc4> in crawl(url, max_urls)
#      79         if total_urls_visited > max_urls:
#      80             break
# ---> 81         crawl(link, max_urls=max_urls)
#
# <ipython-input-65-a7852a03fcc4> in crawl(url, max_urls)
#      79         if total_urls_visited > max_urls:
#      80             break
# ---> 81         crawl(link, max_urls=max_urls)
#
# <ipython-input-65-a7852a03fcc4> in crawl(url, max_urls)
#      75     global total_urls_visited
#      76     total_urls_visited += 1
# ---> 77     links = get_all_website_links(url)
#      78     for link in links:
#      79         if total_urls_visited > max_urls:
#
# <ipython-input-65-a7852a03fcc4> in get_all_website_links(url)
#      34     # domain name of the URL without the protocol
#      35     domain_name = urlparse(url).netloc
# ---> 36     soup = BeautifulSoup(requests.get(url).content, "html.parser")
#      37
#      38     for a_tag in soup.findAll("a"):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in <listcomp>(.0)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     245                     proxies=proxies,
#     246                     allow_redirects=False,
# --> 247                     **adapter_kwargs
#     248                 )
#     249
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     670                 body=body,
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#     674
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                     # Python 3 (including for exceptions like SystemExit).
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     414                 # Python 3
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#     418                     # Remove the TypeError from the exception chain in
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1342         try:
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#    1346                 self.close()
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in begin(self)
#     304         # read until we get a non-100 response
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#     308                 break
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     265
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#     269             raise LineTooLong("status line")
#
# ~/opt/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     311     def recv_into(self, *args, **kwargs):
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#     315             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1837             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1838         else:
# -> 1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# KeyboardInterrupt:

# %%
crawl('https://www.immoweb.be/en/search/house-and-apartment/for-sale?countries=BE&page=1&orderBy=relevance')
print("[+] Total External links:", len(external_urls))
print("[+] Total Internal links:", len(internal_urls))
print("[+] Total:", len(external_urls) + len(internal_urls))
# Out:
# [*] Internal link: https://www.immoweb.be/en/search/house-and-apartment/for-sale/antwerp/province
# [*] Internal link: https://www.immoweb.be/en/search/house-and-apartment/for-sale/brussels/province
# [*] Internal link: https://www.immoweb.be/en/search/house-and-apartment/for-sale/east-flanders/province
# [*] Internal link: https://www.immoweb.be/en/search/house-and-apartment/for-sale/flemish-brabant/province
# [*] Internal link: https://www.immoweb.be/en/search/house-and-apartment/for-sale/hainaut/province
# [*] Internal link: https://www.immoweb.be/en/search/house-and-apartment/for-sale/liege/province
# [*] Internal link: https://www.immoweb.be/en/search/house-and-apartment/for-sale/limburg/province
# [*] Internal link: https://www.immoweb.be/en/search/house-and-apartment/for-sale/luxembourg/province
# [*] Internal link: https://www.immoweb.be/en/search/house-and-apartment/for-sale/namur/province
# [*] Internal link: https://www.immoweb.be/en/search/house-and-apartment/for-sale/walloon-brabant/province
# [*] Internal link: https://www.immoweb.be/en/search/house-and-apartment/for-sale/west-flanders/province
# [*] Internal link: https://www.immoweb.be/en/search/villa/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/apartment-block/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/town-house/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/mansion/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/exceptional-property/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/farmhouse/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/bungalow/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/chalet/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/castle/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/country-cottage/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/mixed-use-building/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/other-properties/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/country-house/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/pavilion/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/loft/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/duplex/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/kot/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/penthouse/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/triplex/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/studio/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/ground-floor/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/service-flat/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/antwerp/province
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/brussels/province
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/east-flanders/province
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/flemish-brabant/province
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/hainaut/province
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/liege/province
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/limburg/province
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/luxembourg/province
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/namur/province
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/walloon-brabant/province
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/west-flanders/province
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/antwerp/district
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/mechelen/district
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/turnhout/district
# [*] Internal link: https://www.immoweb.be/en/search/villa/for-sale/antwerp/district
# [*] Internal link: https://www.immoweb.be/en/search/apartment-block/for-sale/antwerp/district
# [*] Internal link: https://www.immoweb.be/en/search/town-house/for-sale/antwerp/district
# [*] Internal link: https://www.immoweb.be/en/search/mansion/for-sale/antwerp/district
# [*] Internal link: https://www.immoweb.be/en/search/exceptional-property/for-sale/antwerp/district
# [*] Internal link: https://www.immoweb.be/en/search/farmhouse/for-sale/antwerp/district
# [*] Internal link: https://www.immoweb.be/en/search/bungalow/for-sale/antwerp/district
# [*] Internal link: https://www.immoweb.be/en/search/chalet/for-sale/antwerp/district
# [*] Internal link: https://www.immoweb.be/en/search/castle/for-sale/antwerp/district
# [*] Internal link: https://www.immoweb.be/en/search/country-cottage/for-sale/antwerp/district
# [*] Internal link: https://www.immoweb.be/en/search/mixed-use-building/for-sale/antwerp/district
# [*] Internal link: https://www.immoweb.be/en/search/other-properties/for-sale/antwerp/district
# [*] Internal link: https://www.immoweb.be/en/search/country-house/for-sale/antwerp/district
# [*] Internal link: https://www.immoweb.be/en/search/pavilion/for-sale/antwerp/district
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/antwerp/2000
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/antwerp-1/2018
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/antwerp-2/2020
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/antwerp-3/2030
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/antwerp-4/2040
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/antwerp-5/2050
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/antwerp-6/2060
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/zwijndrecht/2070
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/deurne/2100
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/wijnegem/2110
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/borgerhout/2140
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/borsbeek/2150
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/wommelgem/2160
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/merksem/2170
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/ekeren/2180
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/zandhoven/2240
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/pulderbos/2242
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/pulle/2243
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/malle/2390
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/ranst/2520
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/boechout/2530
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/vremde/2531
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/hove/2540
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/lint/2547
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/kontich/2550
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/berchem/2600
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/wilrijk/2610
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/hemiksem/2620
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/schelle/2627
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/aartselaar/2630
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/mortsel/2640
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/edegem/2650
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/hoboken/2660
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/rumst/2840
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/niel/2845
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/boom/2850
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/schoten/2900
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/essen/2910
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/kalmthout/2920
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/brasschaat/2930
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/stabroek/2940
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/kapellen/2950
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/brecht/2960
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/schilde/2970
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/zoersel/2980
# [*] Internal link: https://www.immoweb.be/en/search/house/for-sale/wuustwezel/2990
# [*] Internal link: https://www.immoweb.be/en/search/villa/for-sale/lint/2547
# [*] Internal link: https://www.immoweb.be/en/search/apartment-block/for-sale/lint/2547
# [*] Internal link: https://www.immoweb.be/en/search/town-house/for-sale/lint/2547
# [*] Internal link: https://www.immoweb.be/en/search/mansion/for-sale/lint/2547
# [*] Internal link: https://www.immoweb.be/en/search/exceptional-property/for-sale/lint/2547
# [*] Internal link: https://www.immoweb.be/en/search/farmhouse/for-sale/lint/2547
# [*] Internal link: https://www.immoweb.be/en/search/bungalow/for-sale/lint/2547
# [*] Internal link: https://www.immoweb.be/en/search/chalet/for-sale/lint/2547
# [*] Internal link: https://www.immoweb.be/en/search/castle/for-sale/lint/2547
# [*] Internal link: https://www.immoweb.be/en/search/country-cottage/for-sale/lint/2547
# [*] Internal link: https://www.immoweb.be/en/search/mixed-use-building/for-sale/lint/2547
# [*] Internal link: https://www.immoweb.be/en/search/other-properties/for-sale/lint/2547
# [*] Internal link: https://www.immoweb.be/en/search/country-house/for-sale/lint/2547
# [*] Internal link: https://www.immoweb.be/en/search/pavilion/for-sale/lint/2547
# [*] Internal link: https://www.immoweb.be/en/search/villa/for-sale/antwerp-2/2020
# [*] Internal link: https://www.immoweb.be/en/search/apartment-block/for-sale/antwerp-2/2020
# [*] Internal link: https://www.immoweb.be/en/search/town-house/for-sale/antwerp-2/2020
# [*] Internal link: https://www.immoweb.be/en/search/mansion/for-sale/antwerp-2/2020
# [*] Internal link: https://www.immoweb.be/en/search/exceptional-property/for-sale/antwerp-2/2020
# [*] Internal link: https://www.immoweb.be/en/search/farmhouse/for-sale/antwerp-2/2020
# [*] Internal link: https://www.immoweb.be/en/search/bungalow/for-sale/antwerp-2/2020
# [*] Internal link: https://www.immoweb.be/en/search/chalet/for-sale/antwerp-2/2020
# [*] Internal link: https://www.immoweb.be/en/search/castle/for-sale/antwerp-2/2020
# [*] Internal link: https://www.immoweb.be/en/search/country-cottage/for-sale/antwerp-2/2020
# [*] Internal link: https://www.immoweb.be/en/search/mixed-use-building/for-sale/antwerp-2/2020
# [*] Internal link: https://www.immoweb.be/en/search/other-properties/for-sale/antwerp-2/2020
# [*] Internal link: https://www.immoweb.be/en/search/country-house/for-sale/antwerp-2/2020
# [*] Internal link: https://www.immoweb.be/en/search/pavilion/for-sale/antwerp-2/2020
# [*] Internal link: https://www.immoweb.be/en/search/villa/for-sale/mortsel/2640
# [*] Internal link: https://www.immoweb.be/en/search/apartment-block/for-sale/mortsel/2640
# [*] Internal link: https://www.immoweb.be/en/search/town-house/for-sale/mortsel/2640
# [*] Internal link: https://www.immoweb.be/en/search/mansion/for-sale/mortsel/2640
# [*] Internal link: https://www.immoweb.be/en/search/exceptional-property/for-sale/mortsel/2640
# [*] Internal link: https://www.immoweb.be/en/search/farmhouse/for-sale/mortsel/2640
# [*] Internal link: https://www.immoweb.be/en/search/bungalow/for-sale/mortsel/2640
# [*] Internal link: https://www.immoweb.be/en/search/chalet/for-sale/mortsel/2640
# [*] Internal link: https://www.immoweb.be/en/search/castle/for-sale/mortsel/2640
# [*] Internal link: https://www.immoweb.be/en/search/country-cottage/for-sale/mortsel/2640
# [*] Internal link: https://www.immoweb.be/en/search/mixed-use-building/for-sale/mortsel/2640
# [*] Internal link: https://www.immoweb.be/en/search/other-properties/for-sale/mortsel/2640
# [*] Internal link: https://www.immoweb.be/en/search/country-house/for-sale/mortsel/2640
# [*] Internal link: https://www.immoweb.be/en/search/pavilion/for-sale/mortsel/2640
# [*] Internal link: https://www.immoweb.be/en/search/villa/for-sale/niel/2845
# [*] Internal link: https://www.immoweb.be/en/search/apartment-block/for-sale/niel/2845
# [*] Internal link: https://www.immoweb.be/en/search/town-house/for-sale/niel/2845
# [*] Internal link: https://www.immoweb.be/en/search/mansion/for-sale/niel/2845
# [*] Internal link: https://www.immoweb.be/en/search/exceptional-property/for-sale/niel/2845
# [*] Internal link: https://www.immoweb.be/en/search/farmhouse/for-sale/niel/2845
# [*] Internal link: https://www.immoweb.be/en/search/bungalow/for-sale/niel/2845
# [*] Internal link: https://www.immoweb.be/en/search/chalet/for-sale/niel/2845
# [*] Internal link: https://www.immoweb.be/en/search/castle/for-sale/niel/2845
# [*] Internal link: https://www.immoweb.be/en/search/country-cottage/for-sale/niel/2845
# [*] Internal link: https://www.immoweb.be/en/search/mixed-use-building/for-sale/niel/2845
# [*] Internal link: https://www.immoweb.be/en/search/other-properties/for-sale/niel/2845
# [*] Internal link: https://www.immoweb.be/en/search/country-house/for-sale/niel/2845
# [*] Internal link: https://www.immoweb.be/en/search/pavilion/for-sale/niel/2845
# [*] Internal link: https://www.immoweb.be/en/search/villa/for-sale/brecht/2960
# [*] Internal link: https://www.immoweb.be/en/search/apartment-block/for-sale/brecht/2960
# [*] Internal link: https://www.immoweb.be/en/search/town-house/for-sale/brecht/2960
# [*] Internal link: https://www.immoweb.be/en/search/mansion/for-sale/brecht/2960
# [*] Internal link: https://www.immoweb.be/en/search/exceptional-property/for-sale/brecht/2960
# [*] Internal link: https://www.immoweb.be/en/search/farmhouse/for-sale/brecht/2960
# [*] Internal link: https://www.immoweb.be/en/search/bungalow/for-sale/brecht/2960
# [*] Internal link: https://www.immoweb.be/en/search/chalet/for-sale/brecht/2960
# [*] Internal link: https://www.immoweb.be/en/search/castle/for-sale/brecht/2960
# [*] Internal link: https://www.immoweb.be/en/search/country-cottage/for-sale/brecht/2960
# [*] Internal link: https://www.immoweb.be/en/search/mixed-use-building/for-sale/brecht/2960
# [*] Internal link: https://www.immoweb.be/en/search/other-properties/for-sale/brecht/2960
# [*] Internal link: https://www.immoweb.be/en/search/country-house/for-sale/brecht/2960
# [*] Internal link: https://www.immoweb.be/en/search/pavilion/for-sale/brecht/2960
# [+] Total External links: 57
# [+] Total Internal links: 503
# [+] Total: 560

# %% [markdown]
# [*] Internal link: https://www.immoweb.be/en/search/villa/for-sale - 3698
# [*] Internal link: https://www.immoweb.be/en/search/apartment-block/for-sale - 1333
# [*] Internal link: https://www.immoweb.be/en/search/town-house/for-sale - 421
# [*] Internal link: https://www.immoweb.be/en/search/mansion/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/exceptional-property/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/farmhouse/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/bungalow/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/chalet/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/castle/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/country-cottage/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/mixed-use-building/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/other-properties/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/country-house/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/pavilion/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/loft/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/duplex/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/kot/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/penthouse/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/triplex/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/studio/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/ground-floor/for-sale
# [*] Internal link: https://www.immoweb.be/en/search/service-flat/for-sale

# %%
import requests
from requests import get
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

url = "https://www.immoweb.be/en/search/house-and-apartment/for-sale?countries=BE&page=1&orderBy=relevance"
headers = {"Accept-Language": "en-US, en;q=0.5"}
results = requests.get(url, headers=headers)

soup = BeautifulSoup(results.text, "html.parser")

# link=[]


# #our loop through each container
# for_sale = soup.find_all('div', class_='search-results__item')
    
# for container in for_sale:   
    
#     name = container.h2.a.text
#     link.append(name)

# %%
soup.get.h1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-faca380976c0> in <module>
# ----> 1 soup.get.h1
#
# AttributeError: 'function' object has no attribute 'h1'

# %%
print(link)
# Out:
# []

# %%
<h2 id="card-f2fe0e76-4d34-4b5b-903f-c2fc60fc9e84-title" 
class="card__title card--result__title"><a id="" 
href="https://www.immoweb.be/en/classified/apartment/for-sale/uccle/1180/8892312?searchId=5f51df6beef7c" 
aria-label="Apartment for sale, Uccle (282500€)" class="card__title-link">
                    Apartment
                </a></h2>

# %%
<li class="search-results__item"><article id="classified_8892312" data-fakeid="f2fe0e76-4d34-4b5b-903f-c2fc60fc9e84" class="card card--result card--xl"><div id="lazy-loading-observer-wrapper-18728393-c1ab-4af3-b29f-c559879d79fa-classified_8892312" class="card--result__body"><!----> <h2 id="card-f2fe0e76-4d34-4b5b-903f-c2fc60fc9e84-title" class="card__title card--result__title"><a id="" href="https://www.immoweb.be/en/classified/apartment/for-sale/uccle/1180/8892312?searchId=5f51df6beef7c" aria-label="Apartment for sale, Uccle (282500€)" class="card__title-link">
                    Apartment
                </a></h2> <p class="card--result__price"><span><span aria-hidden="true">€282,500</span> <span class="sr-only">
        282500€
    </span></span></p> <div class="card__informations card--result__informations"><p class="card__information card--result__information card__information--property"><span class="abbreviation"><span aria-hidden="true">
        1 bdr.
    </span> <span class="sr-only">
        1 bedroom
    </span></span> 
                        ·
                     

                        73

                        <span class="abbreviation"><span aria-hidden="true">
        m²
    </span> <span class="sr-only">
        square meters
    </span></span> <!----> <!----></p> <p class="card__information card--results__information--locality card__information--locality">
                1180 Uccle
            </p></div> <div class="card__description card--result__description">
            Proche du parvis Saint-Pierre
        </div> <div class="card__logo-container card--result__logo-container"><img src="https://static.immoweb.be/logos/2352.gif?cache=2016111403293" alt="Latour et Petit Vente" class="card__logo card--result__logo card__logo--xl"></div></div> <div class="card--result__media"><div id="cardMediaContainer-f2fe0e76-4d34-4b5b-903f-c2fc60fc9e84" class="card__media-container"><!----><img src="https://static.immoweb.be/photos/0/8/8/9/2/3/1/2/8892312_1.jpg?cache=20200821030435" id="cardMediaPicture-f2fe0e76-4d34-4b5b-903f-c2fc60fc9e84" class="card__media-picture card--result__media-picture card__media-picture--loaded" alt="property_image"></div> <div class="flag-list"><div class="flag-list__item flag-list__item--main"><span class="flag-list__text">
                new
            </span></div> <div class="flag-list__item flag-list__item--secondary"><!----> <span class="flag-list__text">New build</span></div></div> <!----> <button tabindex="0" aria-label="Save property" class="classified-bookmark"><div class="icon-bookmark"><svg width="24" height="24" viewBox="0 0 24 24" fill="none" xmlns="http://www.w3.org/2000/svg" class="icon-bookmark__heart"><defs><clipPath id="bookmark-mask-89c5aabe-b063-4fb4-babb-91b35d971e0c"><path d="M13.417 20.73a2.095 2.095 0 0 1-2.824-.01l-.115-.105c-5.51-4.986-9.11-8.25-8.974-12.322.063-1.785.976-3.496 2.456-4.503C6.73 1.9 10.152 2.782 12 4.944c1.847-2.162 5.269-3.054 8.04-1.154 1.48 1.007 2.393 2.718 2.456 4.503.147 4.072-3.464 7.336-8.974 12.343l-.105.094z"></path></clipPath></defs> <path d="M13.35 20.307c-.76.69-1.93.69-2.69-.01l-.11-.1C5.3 15.447 1.87 12.337 2 8.457c.06-1.7.93-3.33 2.34-4.29 2.64-1.8 5.9-.96 7.66 1.1 1.76-2.06 5.02-2.91 7.66-1.1 1.41.96 2.28 2.59 2.34 4.29.14 3.88-3.3 6.99-8.55 11.76l-.1.09z" class="icon-bookmark__heart-fill"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M12 5.267c1.76-2.06 5.02-2.9 7.66-1.1 1.4.96 2.28 2.58 2.34 4.28.13 3.88-3.3 6.99-8.55 11.75l-.11.1c-.76.7-1.93.7-2.69.01l-.1-.09-.06-.055C5.274 15.423 1.86 12.322 2 8.457c.06-1.71.94-3.33 2.34-4.29 2.64-1.81 5.9-.96 7.66 1.1zm0 13.56l.1-.1c4.76-4.31 7.9-7.16 7.9-10.05 0-2-1.5-3.5-3.5-3.5-1.54 0-3.04.99-3.56 2.36h-1.87c-.53-1.37-2.03-2.36-3.57-2.36-2 0-3.5 1.5-3.5 3.5 0 2.89 3.14 5.74 7.9 10.05l.1.1z" class="icon-bookmark__heart-border"></path> <g clip-path="url(#bookmark-mask-89c5aabe-b063-4fb4-babb-91b35d971e0c)"><rect height="100%" width="100%" stroke-width="0" class="icon-bookmark__heart-fill-active expect-animation"></rect></g></svg></div></button></div></article> <!----> <!----> <!----> <!----> <!----></li>
