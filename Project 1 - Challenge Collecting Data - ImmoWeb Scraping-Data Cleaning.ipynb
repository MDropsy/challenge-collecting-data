# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_house_apartment.csv')

# %%
df
# Out:
#        locality type_of_property   subtype_of_property   price type_of_sale  \
# 0          1050            house                 house  340000     for sale
# 1          1880            house                 villa  525000     for sale
# 2          4900            house  exceptional property  550000     for sale
# 3          7912            house                 villa  550000     for sale
# 4          6032            house                 house  550000     for sale
# ...         ...              ...                   ...     ...          ...
# 52072      3120            house                 house  455496     for sale
# 52073      1800            house                 house  451650     for sale
# 52074      2018            house                 house  488000     for sale
# 52075      9140            house                 house  455000     for sale
# 52076      9620            house                 house  469000     for sale
#
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50842 entries, 0 to 52076
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   locality                     50842 non-null  int64
#  1   type_of_property             50842 non-null  object
#  2   subtype_of_property          50842 non-null  object
#  3   price                        50842 non-null  object
#  4   type_of_sale                 50842 non-null  object
#  5   number_of_rooms              50840 non-null  float64
#  6   house_area                   50842 non-null  object
#  7   fully_equipped_kitchen       50842 non-null  int64
#  8   furnished                    50842 non-null  object
#  9   open_fire                    50842 non-null  int64
#  10  terrace                      50842 non-null  int64
#  11  terrace_area                 50842 non-null  object
#  12  garden                       50842 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# locality                           0
# type_of_property                   0
# subtype_of_property                0
# price                              0
# type_of_sale                       0
# number_of_rooms                    2
# house_area                         0
# fully_equipped_kitchen             0
# furnished                          0
# open_fire                          0
# terrace                            0
# terrace_area                       0
# garden                             0
# garden_area                        0
# surface_of_the_land            21840
# surface_of_the_plot_of_land        0
# number_of_facades                  0
# swimming_pool                      0
# state_of_the_building              0
# construction_year                  0
# dtype: int64

# %%
df.describe()
# Out:
#            locality  number_of_rooms  fully_equipped_kitchen     open_fire  \
# count  50842.000000     50840.000000            50842.000000  50842.000000
# mean    5388.526081         2.828285                0.654518      0.047303
# std     2958.804834         2.221249                0.475530      0.212289
# min     1000.000000         0.000000                0.000000      0.000000
# 25%     2600.000000         2.000000                0.000000      0.000000
# 50%     5030.000000         3.000000                1.000000      0.000000
# 75%     8420.000000         3.000000                1.000000      0.000000
# max     9992.000000       204.000000                1.000000      1.000000
#
#             terrace        garden  surface_of_the_land  swimming_pool
# count  50842.000000  50842.000000          29002.00000   50842.000000
# mean       0.562960      0.291609            999.31484       0.015676
# std        0.496025      0.454508           5055.03166       0.124220
# ...

# %%
df.describe(include='object')
# Out:
#        type_of_property subtype_of_property   price type_of_sale house_area  \
# count             50842               50842   50842        50842      50842
# unique                2                  24    4220            1        693
# top               house               house  249000     for sale       None
# freq              29002               21810     674        50842       8430
#
#        furnished terrace_area garden_area surface_of_the_land  \
# count      50842        50842       50842               50842
# unique         1          185        1192                3279
# top         None         None        None                None
# freq       50842        33746       42492               21840
#
#        surface_of_the_plot_of_land number_of_facades state_of_the_building  \
# count                        50842             50842                 50842
# unique                           1                 5                     7
# ...

# %%
df.number_of_rooms = df.number_of_rooms.fillna(2)

# %%
df.surface_of_the_land = df.surface_of_the_land.fillna('None')

# %%
df.isnull().sum()
# Out:
# locality                       0
# type_of_property               0
# subtype_of_property            0
# price                          0
# type_of_sale                   0
# number_of_rooms                0
# house_area                     0
# fully_equipped_kitchen         0
# furnished                      0
# open_fire                      0
# terrace                        0
# terrace_area                   0
# garden                         0
# garden_area                    0
# surface_of_the_land            0
# surface_of_the_plot_of_land    0
# number_of_facades              0
# swimming_pool                  0
# state_of_the_building          0
# construction_year              0
# dtype: int64

# %%
df.to_csv('Final_dataset_house_apartment.csv')
